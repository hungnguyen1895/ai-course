# %%
# %matplotlib inline
from mpl_toolkits import mplot3d
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
import numpy as np
np.random.seed(42)

x1s = 2 * np.random.rand(100, 1)
x2s = 2 * np.random.rand(100, 1)

ys = 4 + 3 * x1s + 3 * x2s + np.random.rand(100, 1)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.scatter3D(x1s, x2s, ys)
ax.view_init(25)

# %%
# split the data into training and test sets
# train set
train_x1s = x1s[:80]
train_x2s = x2s[:80]
train_ys = ys[:80]
# test set
test_x1s = x1s[80:]
test_x2s = x2s[80:]
test_ys = ys[80:]

# %% [markdown]
# **Linear regression using numpy**

# %%
# number of epochs
epochs = 10
# learning rate
lr = 0.01

# %%
# initial value for weight w1, w2 and bias b
w1 = np.random.randn(1)
w2 = np.random.randn(1)
b = np.zeros(1)

# %%
for epoch in np.arange(epochs):
  for i in np.arange(80):
    y_pred = w1 * train_x1s[i] + w2 * train_x2s[i] + b
    
    grad_w = (y_pred - train_ys[i]) * train_x1s[i] + (y_pred - train_ys[i]) * train_x2s[i]
    grad_b = (y_pred - train_ys[i])
    
    w1 -= lr * grad_w
    w2 -= lr * grad_w
    b -= lr * grad_b

# %% [markdown]
# **Test** **Loss**

# %%
test_loss = 0
for i in np.arange(20):
  test_loss += 0.5 * (w1 * test_x1s[i] + w2 * test_x2s[i] + b - test_ys[i]) ** 2
test_loss /= 20

# %%
test_loss
# Out:
# array([0.07686418])

# %%
pred_ys = w1 * test_x1s + w2 * test_x2s + b

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.scatter3D(test_x1s, test_ys, pred_ys)
ax.scatter3D(test_x2s, test_ys, pred_ys)
ax.view_init(25)
